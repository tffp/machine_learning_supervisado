# %% [markdown]
# ## Ejercicios
#
# Leer el fichero "pima-indians-diabetes.data.csv" y
# - Lista de los 20 primeros pacientes con menor valor de la variable 2.
# - Para el de la diabetes fragmentar la  columna 8 en dos una con los 1s y otra con los 0s
# - Sacar la media de cada continente,listar todos los continentes por su media
# - Listar todos los países en orden de crecimiento (en porcentaje) en el intervalo de 2002 a 2007

# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# - Lista de los 20 primeros pacientes con menor valor de la variable 2 = BloodPressure

# %%
df_dia = pd.read_csv("pima-indians-diabetes.data.csv",delimiter =",", encoding = "utf-8",header=None) 
df_dia.head(10)
# Out:
#     0    1   2   3    4     5      6   7  8
# 0   6  148  72  35    0  33.6  0.627  50  1
# 1   1   85  66  29    0  26.6  0.351  31  0
# 2   8  183  64   0    0  23.3  0.672  32  1
# 3   1   89  66  23   94  28.1  0.167  21  0
# 4   0  137  40  35  168  43.1  2.288  33  1
# 5   5  116  74   0    0  25.6  0.201  30  0
# 6   3   78  50  32   88  31.0  0.248  26  1
# 7  10  115   0   0    0  35.3  0.134  29  0
# 8   2  197  70  45  543  30.5  0.158  53  1
# 9   8  125  96   0    0   0.0  0.232  54  1

# %%
df_dia.columns = (['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
       'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'])
df_dia.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# ...

# %%
orden_BP = df_dia.sort_values(by=['BloodPressure'])
orden_BP.index
pacientes = []
for i in range(20):
    pacientes.append(orden_BP.index[i])
print("Lista de pacientes con menor presión arterial")
pacientes
# Out:
# Lista de pacientes con menor presión arterial
# [347,
#  494,
#  222,
#  81,
#  78,
#  484,
#  468,
#  60,
#  453,
#  300,
#  261,
#  266,
#  706,
#  49,
#  703,
#  269,
#  435,
#  697,
#  643,
#  430]

# %% [markdown]
# - Para el de la diabetes fragmentar la columna 8 en dos una con los 1s y otra con los 0s

# %%
df_dia3  = df_dia
df_dia3['Outcome0']= df_dia[df_dia['Outcome']== 0]['Outcome']
df_dia3['Outcome1'] = df_dia[df_dia['Outcome']== 1]['Outcome']
df_dia3
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome  Outcome0  Outcome1
# ...

# %% [markdown]
# - Sacar la media de cada continente,listar todos los continentes por su media en los datos "Poblacion_Paises.txt"

# %%
df = pd.read_csv("Poblacion_Paises.txt", encoding = "utf-8") 
df.head(10)
# Out:
#            País Continente   Año  Población
# 1   Afghanistan       Asia  2002   25268405
# 2   Afghanistan       Asia  2007   31889923
# 3       Albania     Europe  2002    3508512
# 4       Albania     Europe  2007    3600523
# 5       Algeria     Africa  2002   31287142
# 6       Algeria     Africa  2007   33333216
# 7        Angola     Africa  2002   10866106
# 8        Angola     Africa  2007   12420476
# 9     Argentina   Americas  2002   38331121
# 10    Argentina   Americas  2007   40301927

# %%
media_asia  = df[df['Continente']=='Asia']['Población'].mean()
media_Africa =  df[df['Continente']=='Africa']['Población'].mean()
media_Americas = df[df['Continente']=='Americas']['Población'].mean()
media_Europe = df[df['Continente']=='Europe']['Población'].mean()
media_Oceania = df[df['Continente']=='Oceania']['Población'].mean()
m = [media_asia,media_Africa,media_Americas,media_Europe,media_Oceania]

# %%
medias = pd.DataFrame(m,['Asia','Africa','Americas','Europe','Oceania'], columns = ['Medias'])
medias
# Out:
#                 Medias
# Asia      1.123296e+08
# Africa    1.695446e+07
# Americas  3.497288e+07
# Europe    1.940537e+07
# Oceania   1.200119e+07

# %% [markdown]
# - Listar todos los países en orden de crecimiento (en porcentaje) en el intervalo de 2002 a 2007

# %%
df_2002 = df[df['Año']==2002]
df_2007 = df[df['Año']==2007]
# con el drop= True para eliminar el index  previo, al concatenar las tablas
df_ext = pd.concat([df_2002.reset_index(drop=True), df_2007.reset_index(drop=True)], axis=1, ignore_index=True)
df_ext.drop(columns=[4,5], inplace=True)
df_ext.columns = ['País','Continente','Año 2002','Población 2002','Año 2007','Población 2007']
df_ext
# Out:
#                    País Continente  Año 2002  Población 2002  Año 2007  \
# 0           Afghanistan       Asia      2002        25268405      2007
# 1               Albania     Europe      2002         3508512      2007
# 2               Algeria     Africa      2002        31287142      2007
# 3                Angola     Africa      2002        10866106      2007
# 4             Argentina   Americas      2002        38331121      2007
# ..                  ...        ...       ...             ...       ...
# 137             Vietnam       Asia      2002        80908147      2007
# 138  West Bank and Gaza       Asia      2002         3389578      2007
# 139         Yemen, Rep.       Asia      2002        18701257      2007
# 140              Zambia     Africa      2002        10595811      2007
# 141            Zimbabwe     Africa      2002        11926563      2007
#
#      Población 2007
# 0          31889923
# 1           3600523
# 2          33333216
# 3          12420476
# ...

# %%
df_ext['Crecimiento'] = df_ext['Población 2007']-df_ext['Población 2002']
df_ext.sort_values(by=['Crecimiento'], ascending=False)
# Out:
#              País Continente  Año 2002  Población 2002  Año 2007  \
# 58          India       Asia      2002      1034172547      2007
# 24          China       Asia      2002      1280400000      2007
# 97       Pakistan       Asia      2002       153403524      2007
# 94        Nigeria     Africa      2002       119901274      2007
# 8      Bangladesh       Asia      2002       135656790      2007
# ..            ...        ...       ...             ...       ...
# 102        Poland     Europe      2002        38625976      2007
# 56        Hungary     Europe      2002        10083313      2007
# 106       Romania     Europe      2002        22404337      2007
# 15       Bulgaria     Europe      2002         7661799      2007
# 117  South Africa     Africa      2002        44433622      2007
#
#      Población 2007  Crecimiento
# 58       1110396331     76223784
# 24       1318683096     38283096
# 97        169270617     15867093
# 94        135031164     15129890
# ...

# %%
df_ext['crecimiento_respecto_07'] = df_ext['Crecimiento'] / df_ext['Población 2007']
df_ext['%_07/02'] = df_ext['Población 2007'] / df_ext['Población 2002']
df_ext
# Out:
#                    País Continente  Año 2002  Población 2002  Año 2007  \
# 0           Afghanistan       Asia      2002        25268405      2007
# 1               Albania     Europe      2002         3508512      2007
# 2               Algeria     Africa      2002        31287142      2007
# 3                Angola     Africa      2002        10866106      2007
# 4             Argentina   Americas      2002        38331121      2007
# ..                  ...        ...       ...             ...       ...
# 137             Vietnam       Asia      2002        80908147      2007
# 138  West Bank and Gaza       Asia      2002         3389578      2007
# 139         Yemen, Rep.       Asia      2002        18701257      2007
# 140              Zambia     Africa      2002        10595811      2007
# 141            Zimbabwe     Africa      2002        11926563      2007
#
#      Población 2007  Crecimiento  porcentaje  crecimiento_respecto_07  \
# ...
